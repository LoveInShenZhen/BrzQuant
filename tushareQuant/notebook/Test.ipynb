# %%
import tushare as ts

df = ts.get_hist_data(code='sz', start='2013-01-01', end='2013-12-31')

if (df.empty):
    print("No data")
else:
    print(df)
# Out:
#                 open      high     close       low      volume  price_change  \
# date
# 2013-12-31  7968.448  8129.261  8121.788  7959.281   8320163.0       122.487
# 2013-12-30  8074.691  8080.703  7999.301  7988.898   8046122.5       -49.553
# 2013-12-27  7911.229  8092.765  8048.854  7893.755   9142418.0       151.529
# 2013-12-26  8067.292  8071.733  7897.325  7887.370   8625506.0      -199.045
# 2013-12-25  8038.211  8119.952  8096.370  7997.364   9793324.0        68.940
# 2013-12-24  8017.248  8125.493  8027.430  7958.366   7083227.0        37.918
# 2013-12-23  7991.342  8023.162  7989.512  7903.079   7091473.5        22.794
# 2013-12-20  8169.216  8175.395  7966.718  7966.718  10687510.0      -180.987
# 2013-12-19  8263.687  8276.942  8147.705  8143.784   7077706.0       -89.243
# 2013-12-18  8220.328  8259.081  8236.948  8193.996   6128879.5        23.516
# 2013-12-17  8282.259  8292.590  8213.432  8207.315   6629471.0       -59.236
# ...
